# %%
#For teting purposes, we will write our code in the function
    #step1: make both words lowercase
word_a = word_a.lower()
word_b = word_b.lower()
def 
    #step3: compare the lenght of both words
